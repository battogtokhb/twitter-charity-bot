# %%
from TwitterAPI import TwitterAPI
import json
import pandas as pd
from pandas.io.json import json_normalize
import authentication as auth

# %%
api = TwitterAPI(auth.consumer_key, auth.consumer_secret, auth.access_token, auth.token_secret)

request = api.request('tweets/search/30day/:Development', {'query': 'we\'ll donate for every retweet to help'})

# %%
print (request)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-18111737e867> in <module>
# ----> 1 print (request)
#
# NameError: name 'request' is not defined

# %%
tweet_raw = []

for item in request:
    tweet_raw.append(item)

# %%
print ((tweet_raw[0]) )
# Out:
# {'created_at': 'Tue Jul 02 20:50:24 +0000 2019', 'id': 1146159208519348227, 'id_str': '1146159208519348227', 'text': 'RT @TripwireInc: Want to help us give back to InfoSec? Just RT to support @CodeClub, and we’ll donate £1 for every retweet and post using #…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 132825381, 'id_str': '132825381', 'name': 'James Spencer', 'screen_name': '1James_Spencer', 'location': None, 'url': None, 'description': "Computer science teacher,  supporter of  LGBTQ+. All thoughts are mine and my asperger's mind #ActuallyAutistic", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 531, 'friends_count': 1753, 'listed_count': 8, 'favourites_count': 4722, 'statuses_count': 3635, 'created_at': 'Wed Apr 14 08:22:57 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1137792333989240833/wzRiVQbL_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1137792333989240833/wzRiVQbL_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Jun 05 11:45:11 +0000 2019', 'id': 1136237525574529025, 'id_str': '1136237525574529025', 'text': 'Want to help us give back to InfoSec? Just RT to support @CodeClub, and we’ll donate £1 for every retweet and post… https://t.co/ccCvRXViPq', 'display_text_range': [0, 140], 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 37711082, 'id_str': '37711082', 'name': 'Tripwire', 'screen_name': 'TripwireInc', 'location': 'Portland, Oregon (PDX)', 'url': 'http://www.tripwire.com', 'description': 'The leading provider of security, compliance and IT operations solutions for enterprises, industrial organizations, service providers and government agencies.', 'translator_type': 'regular', 'protected': False, 'verified': True, 'followers_count': 43883, 'friends_count': 11375, 'listed_count': 1673, 'favourites_count': 31262, 'statuses_count': 55138, 'created_at': 'Mon May 04 17:43:44 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': 'FF8400', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'F1F1F1', 'profile_text_color': '4F4F53', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/930115035803787264/vlm9ASXv_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/930115035803787264/vlm9ASXv_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/37711082/1509531125', ...

# %%
tweet_df = pd.DataFrame(json_normalize(tweet_raw), columns=
    ['text',
    'user.screen_name',
    'created_at',
    'favorite_count',
    'in_reply_to_status_id',
    'retweeted_status',
    'matching_rules'])

# %%
tweet_df
# Out:
#                                                  text user.screen_name  \
# 0   RT @TripwireInc: Want to help us give back to ...   1James_Spencer
# 1   RT @TripwireInc: Want to help us give back to ...          mcmarto
# 2   RT @TripwireInc: Help us give back to InfoSec!...       perlinwarp
# 3   RT @TripwireInc: Want to help us give back to ...     millymollymo
# 4   RT @TripwireInc: Help us give back to InfoSec!...          NilsIRL
# 5   RT @TripwireInc: Want to help us give back to ...         DruWatts
# 6   RT @TripwireInc: Want to help us give back to ...         codeChap
# 7   RT @ZephyrhillsWtr: Retweet and help us keep F...  Jessica24991432
# 8   RT @TripwireInc: Want to help us give back to ...      DuncanSmeed
# 9   RT @TripwireInc: Want to help us give back to ...  ClaireGreenwoo6
# 10  RT @TripwireInc: Want to help us give back to ...       tomholecza
# 11  RT @TripwireInc: Want to help us give back to ...          windy54
# 12  RT @TripwireInc: Want to help us give back to ...         mannzy38
# 13  RT @TripwireInc: Want to help us give back to ...       jockaayush
# 14  RT @TripwireInc: Want to help us give back to ...        davidames
# 15  RT @TripwireInc: Want to help us give back to ...         M1st3r_C
# 16  RT @TripwireInc: Want to help us give back to ...       MaddistonC
# 17  RT @TripwireInc: Want to help us give back to ...       CodeClubNW
# 18  RT @TripwireInc: Want to help us give back to ...       KyleJwilke
# 19  RT @TripwireInc: Want to help us give back to ...   UXinsightsdude
# 20  RT @TripwireInc: Want to help us give back to ...       CodeClubSW
# 21  RT @TripwireInc: Want to help us give back to ...      CodeClubAus
# 22  RT @TripwireInc: Want to help us give back to ...         rdhayler
# 23  RT @TripwireInc: Want to help us give back to ...       PiHardware
# 24  RT @TripwireInc: Want to help us give back to ...  shephallmassive
# 25  RT @TripwireInc: Want to help us give back to ...         recantha
# 26  RT @TripwireInc: Want to help us give back to ...   stewartwatkiss
# 27  RT @TripwireInc: Want to help us give back to ...       ukgrossman
# 28  RT @TripwireInc: Want to help us give back to ...     LearnCompSci
# 29  RT @TripwireInc: Want to help us give back to ...        Lucy17771
# ..                                                ...              ...
# 32  RT @CodeClubNI: Want to help us give back to I...  JulieAn95792067
# 33  RT @TripwireInc: Want to help us give back to ...         a_dinnen
# 34  RT @TripwireInc: Want to help us give back to ...          kezwaha
# 35  RT @TripwireInc: Want to help us give back to ...     will_j_moore
# 36  RT @TripwireInc: Want to help us give back to ...      miltonjonUK
# 37  RT @TripwireInc: Want to help us give back to ...    adamcohenrose
# 38  RT @TripwireInc: Want to help us give back to ...        NuliBouli
# 39  RT @TripwireInc: Want to help us give back to ...        mrradburn
# 40  RT @TripwireInc: Want to help us give back to ...        BrumFaves
# 41  RT @TripwireInc: Want to help us give back to ...     RickieWrites
# 42  RT @TripwireInc: Want to help us give back to ...   CoderDojoDonny
# 43  RT @CodeClubNI: Want to help us give back to I...     dromore_high
# 44  RT @TripwireInc: Want to help us give back to ...    IAmKatharineC
# 45  RT @TripwireInc: Want to help us give back to ...     CannonFodder
# 46  RT @TripwireInc: Want to help us give back to ...       Darrell_VA
# 47  RT @TripwireInc: Want to help us give back to ...          dgbeale
# 48  RT @TripwireInc: Want to help us give back to ...      CodeClubROI
# 49  RT @TripwireInc: Want to help us give back to ...     LMcUnderwood
# 50  RT @TripwireInc: Want to help us give back to ...     TolkienHeads
# 51  RT @CodeClubNI: Want to help us give back to I...       CoderLaois
# 52  RT @TripwireInc: Want to help us give back to ...        louiselmx
# 53  RT @TripwireInc: Want to help us give back to ...      EmilyJelter
# 54  RT @CodeClubNI: Want to help us give back to I...   GrogganPrimary
# 55  RT @TripwireInc: Want to help us give back to ...  GigglingNatalie
# 56  RT @TripwireInc: Want to help us give back to ...    TullamoreDojo
# 57  RT @CodeClubNI: Want to help us give back to I...   steampunk_prof
# 58  RT @TripwireInc: Want to help us give back to ...       linker3000
# 59  RT @TripwireInc: Want to help us give back to ...  ArianneDonoghue
# 60  Want to help us give back to InfoSec? \n\nJust...       CodeClubNI
# 61  RT @TripwireInc: Help us give back to InfoSec!...         decoyle7
#
#                         created_at  favorite_count in_reply_to_status_id  \
# 52  Tue Jun 11 09:28:22 +0000 2019               0                  None
# 53  Tue Jun 11 09:17:41 +0000 2019               0                  None
# 54  Tue Jun 11 08:55:41 +0000 2019               0                  None
# 55  Tue Jun 11 08:43:26 +0000 2019               0                  None
# 56  Tue Jun 11 08:43:10 +0000 2019               0                  None
# 57  Tue Jun 11 08:40:18 +0000 2019               0                  None
# 58  Tue Jun 11 08:39:14 +0000 2019               0                  None
# 59  Tue Jun 11 08:35:02 +0000 2019               0                  None
# 60  Tue Jun 11 08:27:29 +0000 2019               4                  None
# 61  Sun Jun 09 09:15:10 +0000 2019               0                  None
#
#     retweeted_status   matching_rules
# 0                NaN  [{'tag': None}]
# 1                NaN  [{'tag': None}]
# 2                NaN  [{'tag': None}]
# 3                NaN  [{'tag': None}]
# 4                NaN  [{'tag': None}]
# 5                NaN  [{'tag': None}]
# 6                NaN  [{'tag': None}]
# 7                NaN  [{'tag': None}]
# 8                NaN  [{'tag': None}]
# 9                NaN  [{'tag': None}]
# 10               NaN  [{'tag': None}]
# 11               NaN  [{'tag': None}]
# 12               NaN  [{'tag': None}]
# 13               NaN  [{'tag': None}]
# 14               NaN  [{'tag': None}]
# 15               NaN  [{'tag': None}]
# 16               NaN  [{'tag': None}]
# 17               NaN  [{'tag': None}]
# 18               NaN  [{'tag': None}]
# 19               NaN  [{'tag': None}]
# 20               NaN  [{'tag': None}]
# 21               NaN  [{'tag': None}]
# 22               NaN  [{'tag': None}]
# 23               NaN  [{'tag': None}]
# 24               NaN  [{'tag': None}]
# 25               NaN  [{'tag': None}]
# 26               NaN  [{'tag': None}]
# 27               NaN  [{'tag': None}]
# 28               NaN  [{'tag': None}]
# 29               NaN  [{'tag': None}]
# ..               ...              ...
# 32               NaN  [{'tag': None}]
# 33               NaN  [{'tag': None}]
# 34               NaN  [{'tag': None}]
# 35               NaN  [{'tag': None}]
# 36               NaN  [{'tag': None}]
# 37               NaN  [{'tag': None}]
# 38               NaN  [{'tag': None}]
# 39               NaN  [{'tag': None}]
# 40               NaN  [{'tag': None}]
# 41               NaN  [{'tag': None}]
# 42               NaN  [{'tag': None}]
# 43               NaN  [{'tag': None}]
# 44               NaN  [{'tag': None}]
# 45               NaN  [{'tag': None}]
# 46               NaN  [{'tag': None}]
# 47               NaN  [{'tag': None}]
# 48               NaN  [{'tag': None}]
# 49               NaN  [{'tag': None}]
# 50               NaN  [{'tag': None}]
# 51               NaN  [{'tag': None}]
# 52               NaN  [{'tag': None}]
# 53               NaN  [{'tag': None}]
# 54               NaN  [{'tag': None}]
# 55               NaN  [{'tag': None}]
# 56               NaN  [{'tag': None}]
# 57               NaN  [{'tag': None}]
# 58               NaN  [{'tag': None}]
# 59               NaN  [{'tag': None}]
# 60               NaN  [{'tag': None}]
# 61               NaN  [{'tag': None}]
#
# [62 rows x 7 columns]

# %%
tweet_df.to_csv("30DaySandbox.csv", sep='\t')

# %%
((we\'ll OR (we will)) donate for (every OR each) (retweet OR RT) to (help OR support)) OR \
                    (for (every OR each) (RT OR retweet) this tweet gets ((we will) OR we\'ll) donate) OR \
                    (for (every OR each) (RT OR retweet) ((we will) OR we\'ll) donate)
